# %%
# !python src/gridworld.py
# Out:
# State values under uniform random policy:
# [[ 0.  -6.3 -7.4 -5.7]
#  [-5.9 -7.9 -7.9 -5.9]
#  [-5.9 -7.9 -7.9 -5.9]
#  [-5.7 -7.4 -6.3  0. ]]

# %%
# !python src/gridworld_policy_evaluation.py
# Out:
# ...
#   Week 02 — GridWorld MDP
#   Iterative Policy Evaluation (S&B Example 4.1)
# ...
#
# GridWorld(size=4, n_states=16, gamma=1.0)
#   Terminal states : {0, 15}
#   |S| = 16,  |A| = 4
#
# ── Transition model for state 5 (row=1, col=1) ──
#   Action        s′   Reward   Done   Prob
#   ──────────  ────  ───────  ─────  ─────
#   ↑ (0)          1     -1.0  False    1.0
#   ↓ (1)          9     -1.0  False    1.0
#   ← (2)          4     -1.0  False    1.0
#   → (3)          6     -1.0  False    1.0
#
# ── Evaluating uniform random policy (γ=1.0) ──
#   Converged in 167 sweeps  (final max|ΔV| = 9.62e-07)
#
# V(s) — uniform random policy:
#   ────────────────────────────────
#       0.0    -14.0    -20.0    -22.0
#     -14.0    -18.0    -20.0    -20.0
#     -20.0    -20.0    -18.0    -14.0
#     -22.0    -20.0    -14.0      0.0
#   ────────────────────────────────
#
#   S&B ground truth check: ✓ PASS
#   Max absolute error vs. S&B table: 0.000011
#
# S&B ground truth:
# ...

# %%
# !python src/viz.py
# Out:
# ...
#   Week 02 — V(s) Heatmap Visualisation
# ...
#
# Running policy evaluation (uniform random, γ=1) …
#   Converged in 167 sweeps
#   Max |error vs S&B|: 1.05e-05
#
# Generating figures …
#   Saved → value_heatmap.png
#   Saved → sweep_evolution.png
#   Saved → policy_comparison.png

# %%
# !python src/policy_improvement.py
# Out:
# ...
#   Week 02 — Policy Improvement  (S&B §4.2)
#   GridWorld 4×4, γ=1.0
# ...
#
# [ Step 0 ]  Evaluate uniform random policy …
#   Converged in 167 sweeps
#
# V(s) — uniform random π:
#   ────────────────────────────────────
#      0.00   -14.00   -20.00   -22.00
#    -14.00   -18.00   -20.00   -20.00
#    -20.00   -20.00   -18.00   -14.00
#    -22.00   -20.00   -14.00     0.00
#   ────────────────────────────────────
#
# [ Step 1 ]  Compute Q(s,a) for every (state, action) pair …
#   Q shape: (16, 4)  (n_states × n_actions)
#
#   Q-values for selected states:
#   State           ↑        ↓        ←        →    greedy
#   ────────  ───────  ───────  ───────  ───────  ────────
#   s=1        -15.00   -19.00    -1.00   -21.00         ←
#   s=4         -1.00   -21.00   -15.00   -19.00         ↑
#   s=5        -15.00   -21.00   -15.00   -21.00         ↑
#   s=6        -21.00   -19.00   -19.00   -21.00         ←
#   s=9        -19.00   -21.00   -21.00   -19.00         ↑
# ...
