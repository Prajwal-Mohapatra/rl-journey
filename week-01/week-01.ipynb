# %%
# !python src/cartpole_random.py
# Out:
# Episode 10: reward=24.0
# Episode 20: reward=18.0
# Episode 30: reward=11.0
# Episode 40: reward=33.0
# Episode 50: reward=12.0
# Episode 60: reward=12.0
# Episode 70: reward=13.0
# Episode 80: reward=34.0
# Episode 90: reward=38.0
# Episode 100: reward=10.0
# Figure(640x480)

# %%
# !python src/custom_rl_loop.py
# Out:
# Starting Training... Watch the Q-Table evolve!
# --------------------------------------------------
# Episode 10 | Epsilon: 0.54
# State | Q(Left) | Q(Right)
# --------------------------
#   1   |  -0.47  |   0.00
#   2   |   0.00  |   0.00
#   3   |   0.00  |   0.01
#   4   |   0.00  |   0.05
#   5   |   0.00  |   0.34
# --------------------------
# Episode 20 | Epsilon: 0.32
# State | Q(Left) | Q(Right)
# --------------------------
#   1   |  -0.47  |   0.00
#   2   |   0.00  |   0.02
#   3   |   0.00  |   0.19
#   4   |   0.04  |   0.42
#   5   |   0.05  |   0.77
# --------------------------
# Episode 30 | Epsilon: 0.19
# State | Q(Left) | Q(Right)
# --------------------------
#   1   |  -0.47  |   0.00
#   2   |   0.00  |   0.06
#   3   |   0.01  |   0.44
#   4   |   0.12  |   0.66
#   5   |   0.09  |   0.92
# --------------------------
# Episode 40 | Epsilon: 0.12
# State | Q(Left) | Q(Right)
# --------------------------
#   1   |  -0.47  |   0.00
#   2   |   0.00  |   0.06
# ...

# %%
# !python src/custom_rl_loop_2.py
# Out:
# ...
#   Week 01 — Hand-rolled RL Loop
#   Environment : LinearCorridor (custom, no Gymnasium)
#   Agent       : Q-learning with epsilon-greedy exploration
# ...
#
# LinearCorridor(n_cells=10, slip_prob=0.0, max_steps=200)
# EpsilonGreedyAgent(alpha=0.1, gamma=0.99, epsilon=1.000)
#
# Training...
#   Episode    1 | avg reward:  +5.40 | win rate: 100.0% | ε=0.997 | steps:  47
#   Episode  100 | avg reward:  +5.04 | win rate:  99.0% | ε=0.729 | steps:  17
#   Episode  200 | avg reward:  +8.08 | win rate: 100.0% | ε=0.457 | steps:  12
#   Episode  300 | avg reward:  +8.75 | win rate: 100.0% | ε=0.186 | steps:  11
#   Episode  400 | avg reward:  +9.10 | win rate: 100.0% | ε=0.050 | steps:   9
#   Episode  500 | avg reward:  +9.16 | win rate: 100.0% | ε=0.050 | steps:   9
#
# Evaluating learned policy (greedy)...
#
# ── Eval episode 1 ──
#   A · · · · · · · · G  (step 0)
#   S A · · · · · · · G  (step 1)  action=→
#   S · A · · · · · · G  (step 2)  action=→
#   S · · A · · · · · G  (step 3)  action=→
# ...

# %%
# !python src/reward_plot.py
# Out:
# ...
#   Week 01 — Reward Tracking Plot
#   episodes=500  cells=10  α=0.1  γ=0.99  slip=0.0
# ...
#
# Training …
#   Episode    1 | avg reward:  +7.00 | win rate: 100.0% | ε=0.997 | steps:  31
#   Episode  100 | avg reward:  +5.53 | win rate: 100.0% | ε=0.729 | steps:  40
#   Episode  200 | avg reward:  +8.10 | win rate: 100.0% | ε=0.457 | steps:  13
#   Episode  300 | avg reward:  +8.84 | win rate: 100.0% | ε=0.186 | steps:  11
#   Episode  400 | avg reward:  +9.11 | win rate: 100.0% | ε=0.050 | steps:   9
#   Episode  500 | avg reward:  +9.16 | win rate: 100.0% | ε=0.050 | steps:   9
#
# ────────────────────────────────────────
#   Total episodes   : 500
#   Overall win rate : 100.0%
#   Mean reward      : +8.149
#   Std  reward      : 2.293
#   Min / Max        : -12.10 / +9.20
#   Cumulative       : +4,074.4
#
#   Last-20% avg     : +9.162  (win rate 100.0%)
# ────────────────────────────────────────
#
# Generating reward tracking plot (window=40) …
# Plot saved → reward_tracking.png
# ...
